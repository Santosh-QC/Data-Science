# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#job data 

job_data = ['20', '20', '20', '20', '20']
labels = 'IT', 'Finance', 'Ops', 'R&D', 'sales'
explode = (0, 0, 0, 0, 0)
plt.pie(job_data, explode=explode, labels=labels)
plt.show()
