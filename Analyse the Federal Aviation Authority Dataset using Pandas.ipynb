# %%
import pandas as pd

pd.set_option("display.max.columns", None)
df_aviation = pd.read_csv('faa_ai_prelim.csv')
df_aviation.columns
# Out:
# Index(['UPDATED', 'ENTRY_DATE', 'EVENT_LCL_DATE', 'EVENT_LCL_TIME',
#        'LOC_CITY_NAME', 'LOC_STATE_NAME', 'LOC_CNTRY_NAME', 'RMK_TEXT',
#        'EVENT_TYPE_DESC', 'FSDO_DESC', 'REGIST_NBR', 'FLT_NBR', 'ACFT_OPRTR',
#        'ACFT_MAKE_NAME', 'ACFT_MODEL_NAME', 'ACFT_MISSING_FLAG',
#        'ACFT_DMG_DESC', 'FLT_ACTIVITY', 'FLT_PHASE', 'FAR_PART', 'MAX_INJ_LVL',
#        'FATAL_FLAG', 'FLT_CRW_INJ_NONE', 'FLT_CRW_INJ_MINOR',
#        'FLT_CRW_INJ_SERIOUS', 'FLT_CRW_INJ_FATAL', 'FLT_CRW_INJ_UNK',
#        'CBN_CRW_INJ_NONE', 'CBN_CRW_INJ_MINOR', 'CBN_CRW_INJ_SERIOUS',
#        'CBN_CRW_INJ_FATAL', 'CBN_CRW_INJ_UNK', 'PAX_INJ_NONE', 'PAX_INJ_MINOR',
#        'PAX_INJ_SERIOUS', 'PAX_INJ_FATAL', 'PAX_INJ_UNK', 'GRND_INJ_NONE',
#        'GRND_INJ_MINOR', 'GRND_INJ_SERIOUS', 'GRND_INJ_FATAL', 'GRND_INJ_UNK'],
#       dtype='object')

# %%
df_aviation.ACFT_MAKE_NAME.shape
# Out:
# (83,)

# %%
df_aviation_dataset = pd.read_csv('faa_ai_prelim.csv')[['ACFT_MAKE_NAME', 'LOC_STATE_NAME', 'ACFT_MODEL_NAME', 'RMK_TEXT', 'FLT_PHASE', 'EVENT_TYPE_DESC', 'FATAL_FLAG']]
df_aviation_dataset
# Out:
#     ACFT_MAKE_NAME  LOC_STATE_NAME ACFT_MODEL_NAME  \
# 0            BEECH  North Carolina              36
# 1             VANS         Florida             RV7
# 2           CESSNA      New Jersey             172
# 3          LANCAIR  North Carolina             235
# 4           CESSNA          Alaska             172
# ..             ...             ...             ...
# 78         AERONCA           Texas            O58B
# 79  NORTH AMERICAN         Arizona             F51
# 80        CHAMPION      California           8KCAB
# 81           BEECH      California              35
# 82          CESSNA         Alabama             182
#
#                                              RMK_TEXT       FLT_PHASE  \
# 0   AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...   UNKNOWN (UNK)
# 1   AIRCRAFT ON LANDING WENT OFF THE END OF THE RU...   LANDING (LDG)
# 2   AIRCRAFT ON FINAL SUSTAINED A BIRD STRIKE, LAN...  APPROACH (APR)
# ...

# %%
df_aviation_dataset['FATAL_FLAG'].fillna(value="No", inplace=True)

# %%
df_aviation_dataset
# Out:
#     ACFT_MAKE_NAME  LOC_STATE_NAME ACFT_MODEL_NAME  \
# 0            BEECH  North Carolina              36
# 1             VANS         Florida             RV7
# 2           CESSNA      New Jersey             172
# 3          LANCAIR  North Carolina             235
# 4           CESSNA          Alaska             172
# ..             ...             ...             ...
# 78         AERONCA           Texas            O58B
# 79  NORTH AMERICAN         Arizona             F51
# 80        CHAMPION      California           8KCAB
# 81           BEECH      California              35
# 82          CESSNA         Alabama             182
#
#                                              RMK_TEXT       FLT_PHASE  \
# 0   AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...   UNKNOWN (UNK)
# 1   AIRCRAFT ON LANDING WENT OFF THE END OF THE RU...   LANDING (LDG)
# 2   AIRCRAFT ON FINAL SUSTAINED A BIRD STRIKE, LAN...  APPROACH (APR)
# ...

# %%
df_aviation_dataset.ACFT_MAKE_NAME.value_counts()
# Out:
# CESSNA                    23
# PIPER                     10
# BEECH                      9
# MOONEY                     4
# BOEING                     3
# CHAMPION                   2
# SOCATA                     2
# BELL                       2
# LANCAIR                    2
# PITTS                      1
# SABRELINER                 1
# ENSTROM                    1
# NORTH AMERICAN             1
# FLIGHT DESIGN              1
# FAIRCHILD                  1
# AEROSTAR INTERNATIONAL     1
# CONSOLIDATED VULTEE        1
# AERONCA                    1
# AIRBUS                     1
# GREAT LAKES                1
# MAULE                      1
# VANS                       1
# AERO COMMANDER             1
# SAAB                       1
# GULFSTREAM                 1
# CHRISTEN                   1
# GLOBE                      1
# HUGHES                     1
# GRUMMAN                    1
# EMBRAER                    1
# Name: ACFT_MAKE_NAME, dtype: int64

# %%
for i in df_aviation_dataset.FATAL_FLAG:
    if i == "Yes":
        print("fatal flag observations: {}". format(i))
    
fatal_flag_obs= df_aviation_dataset.groupby('FATAL_FLAG')
fatal_flag_obs.size()
# Out:
# fatal flag observations: Yes
# fatal flag observations: Yes
# fatal flag observations: Yes
# fatal flag observations: Yes
# fatal flag observations: Yes
# fatal flag observations: Yes
# fatal flag observations: Yes
# fatal flag observations: Yes
# FATAL_FLAG
# Yes    8
# dtype: int64

# %%
accidents_with_fatality = fatal_flag_obs.get_group('Yes')
accidents_with_fatality
# Out:
#     ACFT_MAKE_NAME  LOC_STATE_NAME ACFT_MODEL_NAME  \
# 0            BEECH  North Carolina              36
# 22             NaN         Arizona             NaN
# 53           PIPER         Florida            PA28
# 55   FLIGHT DESIGN      California            CTLS
# 79  NORTH AMERICAN         Arizona             F51
# 80        CHAMPION      California           8KCAB
# 81           BEECH      California              35
# 82          CESSNA         Alabama             182
#
#                                              RMK_TEXT      FLT_PHASE  \
# 0   AIRCRAFT CRASHED INTO TREES, THE 1 PERSON ON B...  UNKNOWN (UNK)
# 22  AIRCRAFT, LIGHT SPORT EVOLUTION REVO,  ON TAKE...  TAKEOFF (TOF)
# 53  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES. ...  UNKNOWN (UNK)
# 55  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES A...  UNKNOWN (UNK)
# 79  AIRCRAFT CRASHED UNDER UNKNOWN CIRCUMSTANCES, ...  UNKNOWN (UNK)
# 80  N9872R, BEECH M35 AIRCRAFT, AND N5057G, BELLAN...  UNKNOWN (UNK)
# ...

# %%
df_aircraft_name_null = df_aviation_dataset.ACFT_MAKE_NAME.dropna
df_aircraft_name_null()
# Out:
# 0              BEECH
# 1               VANS
# 2             CESSNA
# 3            LANCAIR
# 4             CESSNA
#            ...
# 78           AERONCA
# 79    NORTH AMERICAN
# 80          CHAMPION
# 81             BEECH
# 82            CESSNA
# Name: ACFT_MAKE_NAME, Length: 78, dtype: object

# %%
#df_final = df_aviation_dataset.dropna(subset=['ACFT_MAKE_NAME'])
#df_final.shape
